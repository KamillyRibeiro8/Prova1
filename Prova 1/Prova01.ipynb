# %%
while True:
    idade = int(input("Qual a sua idade?:"))
    valor = float(input("Qual o valor total da na sua carteira?:"))
    if idade < 16:
     print("Entrada permitida apenas com acompanhante.")
    elif idade >= 16:
        if valor >= 30:
            print("Ingresso comprado! Bom filme.")
        else:
            print("Saldo insuficiente para o ingresso.")
        
    resposta = input("Deseja verificar outro cliente (s/n)?: ")
    if resposta == 'n':
        print("Atendimento encerrando.")
        break
# Out:
# Qual a sua idade?: 15
# Qual o valor total da na sua carteira?: 16
# Entrada permitida apenas com acompanhante.
# Deseja verificar outro cliente (s/n)?:  s
# Qual a sua idade?: 16
# Qual o valor total da na sua carteira?: 20
# Saldo insuficiente para o ingresso.
# Deseja verificar outro cliente (s/n)?:  s
# Qual a sua idade?: 16
# Qual o valor total da na sua carteira?: 35
# Ingresso comprado! Bom filme.
# Deseja verificar outro cliente (s/n)?:  n
# Atendimento encerrando.
